# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from six.moves import cPickle
from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.contrib.layers import xavier_initializer
import shutil
% matplotlib inline

# %%
from PIL import Image

# %%
img = Image.open("./data/abathur.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1181x751 at 0x2352E6F3BE0>

# %%
resize_img = img.resize((450,450))

image = np.array(resize_img)
image.shape
# Out:
# (450, 450, 3)

# %%
plt.imshow(image)
plt.show()

# %%
image = image.reshape(1, 450, 450, 3)
print(image.shape)
plt.imshow(image[0])
plt.show()
# Out:
# (1, 450, 450, 3)
